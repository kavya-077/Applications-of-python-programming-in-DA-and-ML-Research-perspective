# %% [markdown]
# <a href="https://colab.research.google.com/github/kavya-077/Applications-of-python-programming-in-DA-and-ML-Research-perspective/blob/master/Day_2_Session_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# print multiples of 3 upto 200 using a list

# %%
def multiple(m, n): 
    a = range(n, (m * n)+1, n)   
    print(*a)   
m = 66
n = 3
multiple(m, n)
# Out:
# 3 6 9 12 15 18 21 24 27 30 33 36 39 42 45 48 51 54 57 60 63 66 69 72 75 78 81 84 87 90 93 96 99 102 105 108 111 114 117 120 123 126 129 132 135 138 141 144 147 150 153 156 159 162 165 168 171 174 177 180 183 186 189 192 195 198

# %% [markdown]
# print the nos only divisable by 5 and 7 between 1000 and 2000 using a list( both inclusive)

# %%
nl=[]
for x in range(1000, 2000):
    if (x%7==0) and (x%5==0):
        nl.append(str(x))
print (','.join(nl))
# Out:
# 1015,1050,1085,1120,1155,1190,1225,1260,1295,1330,1365,1400,1435,1470,1505,1540,1575,1610,1645,1680,1715,1750,1785,1820,1855,1890,1925,1960,1995

# %% [markdown]
# Add the n number of names in a list and print them alphabetically and reverse alphabetically.

# %%
locations = list(input().split())

print("Original order:")
print(locations)

print("\nAlphabetical:")
print(sorted(locations))
print("\nReverse alphabetical:")
print(sorted(locations, reverse=True))
# Out:
# kavya divya bavya navya shravya
# Original order:
# ['kavya', 'divya', 'bavya', 'navya', 'shravya']
#
# Alphabetical:
# ['bavya', 'divya', 'kavya', 'navya', 'shravya']
#
# Reverse alphabetical:
# ['shravya', 'navya', 'kavya', 'divya', 'bavya']

# %% [markdown]
# Print  perfect squares and divisible by 5 between 500 and 1000( (both inclusive) using list

# %%
lower=int(input("Enter lower range limit:"))
upper=int(input("Enter upper range limit:"))
n=int(input("Enter the number to be divided by:"))
for i in range(lower,upper+1):
    if(i%n==0):
        print(i)
# Out:
# Enter lower range limit:225
# Enter upper range limit:343
# Enter the number to be divided by:5
# 225
# 230
# 235
# 240
# 245
# 250
# 255
# 260
# 265
# 270
# 275
# 280
# 285
# 290
# 295
# 300
# 305
# 310
# 315
# 320
# 325
# 330
# 335
# 340

# %% [markdown]
# Get  a string and store word by word as elements in a tuple and find the largest word in the  tuple and print it

# %%
a=[]
n= int(input("Enter the number of elements in list:"))
for x in range(0,n):
    element=input("Enter element" + str(x+1) + ":")
    a.append(element)
max1=len(a[0])
temp=a[0]
for i in a:
    if(len(i)>max1):
       max1=len(i)
       temp=i
print("The word with the longest length is:")
print(temp)
# Out:
# Enter the number of elements in list:10
# Enter element1:2
# Enter element2:3
# Enter element3:4
# Enter element4:
# Enter element5:5
# Enter element6:6
# Enter element7:7
# Enter element8:8
# Enter element9:9
# Enter element10:1
# The word with the longest length is:
# 2

# %% [markdown]
# Get rollno and marks (Rollno, mark) as list of tuples for n number of students through keyboard  and print them in marks descending order with rollno.

# %%
print(sorted([(input("Enter rollno: "), input("Enter marks: ")) for i in range(int(input("Enter number of students")))], key=lambda x: x[1],reverse=True))
# Out:
# Enter number of students5
# Enter rollno: 1
# Enter marks: 23
# Enter rollno: 2
# Enter marks: 34
# Enter rollno: 3
# Enter marks: 55
# Enter rollno: 6
# Enter marks: 34
# Enter rollno: 5
# Enter marks: 67
# [('5', '67'), ('3', '55'), ('2', '34'), ('6', '34'), ('1', '23')]

# %% [markdown]
# Get name and salary (name, salary) as list of tuples for n number of employees through keyboard  and print them in name alphabetical order with salary

# %%
print(sorted([(input("Enter name: "), input("Enter salary: ")) for i in range(int(input("Enter number of employees")))], key=lambda x: x[0]))
# Out:
# Enter number of employees2
# Enter name: kavya
# Enter salary: 1000000
# Enter name: divya
# Enter salary: 12345678
# [('divya', '12345678'), ('kavya', '1000000')]
